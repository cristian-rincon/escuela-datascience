# %% [markdown]
# <a href="https://colab.research.google.com/github/cristian-rincon/escuela-datascience/blob/master/introduccion_web_scraping/scraping_et.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url_base = "https://eltiempo.com"

# %%
eltiempo = requests.get(url_base)
eltiempo.status_code
# Out:
# 200

# %% [markdown]
# ## Importando BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
et_soup = BeautifulSoup(eltiempo.text,'lxml')
type(et_soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Menú principal del periódico

# %%
menu = et_soup.find('ul', attrs={'class':'default-menu'}).find_all('li')

# %%
colombia_item = menu[1]
colombia_item
# Out:
# <li class="colombia" itemprop="name">
# <a href="/colombia" itemprop="url">Colombia</a>
# </li>

# %% [markdown]
# ### Obteniendo el texto al interior de una etiqueta

# %%
colombia_item.a.get_text()
# Out:
# 'Colombia'

# %% [markdown]
# ### Obteniendo el link de la etiqueta a

# %%
colombia_item.a.get('href')
# Out:
# '/colombia'

# %%
menu_links = [menu_item.a.get('href') for menu_item in menu]
menu_links
# Out:
# ['/opinion',
#  '/colombia',
#  '/bogota',
#  '/mundo',
#  '/politica',
#  '/justicia',
#  '/economia',
#  '/deportes',
#  '/cultura',
#  '/tecnosfera',
#  '/vida',
#  '/salud',
#  '/unidad-investigativa',
#  '/multimedia/videos']

# %%
colombia_section = requests.get(url_base + menu_links[1])
colombia_section
# Out:
# <Response [200]>

# %%
colombia_soup = BeautifulSoup(colombia_section.text, 'lxml')
colombia_soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <script type="text/javascript">\n   var _sf_startpt=(new Date()).getTime()\n  </script>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){j++,L=y.hash,this[u]=x.now()}function o(){j--,y.hash!==L&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),N=t("ee"),S=N.get("tracer");t(16),x.features.spa=!0;var L,j=0;N.on(u,r),N.on(p,r),N.on(d,o),N.on(l,o),N.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(N,"xhr-resolved"),a(N,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,j>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+l,function ...

# %% [markdown]
# ### Obteniendo el artículo principal

# %%
def get_feature_article(soup):
    feature_article = soup.find('div',attrs={'class':'apertura-seccion'})
    article_link = feature_article.a.get('href')
    return article_link

# %%
get_feature_article(colombia_soup)
# Out:
# '/colombia/cali'

# %% [markdown]
# ### Obteniendo la lista de artículos secundarios

# %%
def get_articles_list(soup):
    articles_list = []
    feature_article = get_feature_article(soup)
    if feature_article:
        articles_list.append(feature_article)
    posts_list = soup.find('div',attrs={'class':'notas-col-izq'})
    for article in posts_list.find_all('a'):
        articles_list.append(article.get('href'))
    return list(set(articles_list))

# %%
# Revisar set() para eliminar los duplicados de la lista, convertir de nuevo en una lista 
# https://docs.python.org/3.8/library/stdtypes.html#set-types-set-frozenset
articles_list = get_articles_list(colombia_soup)
articles_list
# Out:
# ['/colombia/cali/masacre-de-llano-verde-alcalde-de-cali-pidio-que-el-fbi-investigue-la-masacre-en-cali-colombia-534086',
#  '/contenido-comercial/vision-colaborativa-para-generar-valor-a-las-empresas-colombianas-532698',
#  '/colombia/otras-ciudades/sos-cartagena-alimentacion-solidaria-restaurantes-y-hoteles-llevan-comida-a-los-mas-necesitados-534166',
#  '/contenido-comercial',
#  '/colombia/cali/noticias-de-cali-ordenan-arresto-contra-gobernadora-del-valle-del-cauca-por-una-tutela-534328',
#  '/colombia/otras-ciudades/reapertura-santa-marta-abrira-sus-playas-el-primer-fin-de-semana-de-septiembre-534424',
#  '/colombia/cali/noticias-de-cali-mataron-a-la-exesposa-de-el-sobrino-aliado-del-clan-comba-ultimas-noticias-534296',
#  '/colombia/otras-ciudades',
#  '/colombia/cali/ultimo-adios-a-seis-jovenes-asesinados-en-el-tambo-cauca-534226',
#  '/colombia/cali',
#  None]

# %% [markdown]
# ### Obtener la información de un artículo

# %%
def scrap_article(url_article):
    try:
        article = requests.get(url_article)
        if article.status_code == 200:
            article_soup = BeautifulSoup(article.text,'html5lib') # .prettify()
            # Extracting Title
            title = article_soup.find('h1', attrs={'class':'titulo'})
            print(title.text)
            # Extracting volanta
            volanta = article_soup.find('p', attrs={'class':'info'})
            print(volanta.text)
            # Extracting date
            date = article_soup.find('span', attrs={'class':'fecha'})
            print(date.text)
            # Extracting Author
            author = article_soup.find('span', attrs={'class':'nombre'})
            print(author.text)
            # Extracting text
            text = article_soup.find_all('p', attrs={'class':'contenido'})
            for t in text:
                print(t.text)
    except Exception as e:
        print('Ha ocurrido un error con la extracción del artículo.')
        print(e)
        print('\n')

# %%
# !pip install -U beautifulsoup4

# %%
article_test = url_base + articles_list[0]
# article_test
# article_test = requests.get(article_test)
# article_soup = BeautifulSoup(article_test.text,'lxml').prettify()
#scrap_article(article_test)
article_test
# Out:
# 'https://eltiempo.com/colombia/cali/masacre-de-llano-verde-alcalde-de-cali-pidio-que-el-fbi-investigue-la-masacre-en-cali-colombia-534086'

# %%
scrap_article(article_test)
# Out:
# Alcalde de Cali pidió que el FBI investigue la masacre de Llano Verde
# El mandatario le hizo esta solicitud al fiscal general de la Nación, Francisco Barbosa.
#
# 27 de agosto 2020 , 05:45 p.m.
#
# Cali
# El alcalde de Cali, Jorge Iván Ospina, a través de una carta enviada al Fiscal General de la Nación, Francisco Barbosa, solicitó que el FBI (Federal Bureau of Investigation) acompañe la investigación de la masacre de cinco menores de edad que conmocionó a toda la ciudad y el país el pasado 11 de agosto en el oriente  de esta capital del Valle.(Le recomendamos leer: El día cuando un presidente colombiano ordenó fusilar a su sobrino)
# %%
scrap_article(url_base + articles_list[1])
# Out:
# Visión colaborativa para generar valor a las empresas colombianas
# La multinacional busca aliados que enriquezcan su ecosistema de ‘software’ empresarial.
#
# 26 de agosto 2020 , 10:00 p.m.
#
# CONTENIDO PATROCINADO
# Las perspectivas de crecimiento de Siesa -la multinacional de origen vallecaucano, hoy referente de desarrollo de ‘software’ para empresas- pasan por consolidarse como un gran integrador de soluciones tecnológicas propias y de terceros.
# En su balance de resultados del 2019, los directivos de la compañía destacaron que uno de los éxitos más importantes fue el fortalecimiento de su portafolio de la mano de un ecosistema de soluciones más completo, gracias al trabajo mancomunado con cerca de 30 aliados. Hoy por hoy, la visión colaborativa de Siesa no solo continúa dando frutos, sino que sigue siendo la principal locomotora de su crecimiento y expansión en los diferentes países latinoamericanos donde tiene presencia.Esta filosofía es la clave de Siesa para atender las distintas necesidades de sus clientes, desde la base de la pirámide hasta las empresas más grandes del país, enriqueciendo su propuesta de valor.Alianzas, un pilar estratégicoComo referente del mercado nacional, Siesa recibe constantemente solicitudes de proveedores de soluciones de ‘software’ y servicios que buscan integrarse con su ecosistema de soluciones empresariales. Con el objetivo de formalizar la evaluación y gestión de estas solicitudes, la compañía creó recientemente una dirección de alianzas. Según explica José Luis Moreno, director de Mercadeo y Ventas de Siesa, “el reto de esta área es buscar aliados que agreguen valor al cliente. Se hace un proceso de evaluación de la calidad del producto o solución ofrecida, igualmente se investiga la experiencia, recomendación y satisfacción de los clientes con cada posible aliado. Basándonos en esta información, se toma la decisión de integración”.De acuerdo con Moreno, en este momento la compañía está enfocada en sumar nuevos servicios transaccionales y herramientas de inteligencia artificial que permitan crear modelos de análisis predictivo.Ecosistema en permanente evoluciónPara cumplir con los requerimientos actuales, urgentes y futuros del mundo empresarial, Siesa ha construido a lo largo de los años un ecosistema de aplicaciones propias y de terceros que operan principalmente en la nube y se integran de forma natural, aprovechando las últimas tecnologías en desarrollo de ‘software’ enfocadas en la experiencia de usuario y la facilidad de uso para el cliente final.Lo anterior, sumado a una estrategia de diversificación de productos, es la clave de Siesa para penetrar en todos los segmentos empresariales mientras continúa consolidándose en el mercado nacional.El por qué de la diversificaciónSiesa se ha propuesto poner al alcance de su base instalada de más de 10.000 clientes una oferta de valor que les permita cubrir todos sus procesos sin las dificultades, demoras y otros lastres que se producen al tener que tratar con múltiples proveedores.Por ejemplo, recientemente amplió su portafolio con la integración de servicios asociados a las transacciones generadas entre proveedores y clientes como la facturación electrónica, domicilios y pasarelas de pago.“Estamos en un proceso de actualización permanente a nuevas tecnologías, integración de todas las soluciones a la nube (manteniéndonos como el proveedor de mayor crecimiento en este segmento) y consolidación de la oferta de servicios relacionados con las transacciones generadas entre clientes y proveedores en los sectores en los cuales competimos”, acota el director de Mercadeo y Ventas de Siesa.En la misma línea, para garantizar la continuidad del servicio de Siesa y de la operación con sus clientes, la compañía avanza en un modelo de microimplementaciones y ‘continuous delivery’ para cada una de sus soluciones.La inteligencia de negocios ya está aquíLos aplicativos de Siesa van más allá de la extracción y el análisis de información. Sin importar el sector o el giro de negocio, la multinacional hoy provee modelos que permiten hacer análisis predictivos para disminuir la incertidumbre del futuro. Una evolución que, por ejemplo, permite conocer la respuesta del consumidor ante diferentes dinámicas comerciales y, de esta manera, mejorar la experiencia de los clientes durante el proceso de compra.
# Siesa logra optimizar la gestión empresarial en sectores como manufactura, domicilios y comercio.
# El crecimiento de Siesa hoy se concentra en tres iniciativas: en primer lugar, la migración de sus soluciones a lenguajes de última tecnología o de última generación: “si bien muchos de nuestros aplicativos se han desarrollado en estos lenguajes, la idea es lograr que el 100 por ciento cumplan con esta condición”, afirma José Luis Moreno, director de Mercado y Ventas de Siesa. En segundo lugar, la compañía dirige esfuerzos para lograr que las interfaces de sus productos sean cada vez más amigables.Por último, la multinacional ya cuenta con una aplicación móvil donde los clientes pueden visualizar datos relevantes que entregan las soluciones que han adquirido, a través de ‘dashboards’ que entregan información para cada área de la compañía. “Se pueden llevar a cabo tareas de diferentes procesos desde un dispositivo móvil, sin necesidad de ingresar al aplicativo desde un computador de escritorio”, explica Moreno.A estas tres iniciativas se suma el fortalecimiento de su ecosistema de aplicativos, por medio de las alianzas con soluciones de terceros. Estos son algunos de los logros de la visión colaborativa de Siesa:Manufactura, 'retail' y gestión de proyectos, casos de éxitoPara empresas con procesos de manufactura o comercialización, en las cuales la gestión y el control de inventarios es una variable crítica, Siesa se integra con empresas nacionales como WA Solutions que trabaja sobre el modelo DDMRP (una innovadora metodología para la planificación y gestión de inventarios y materiales que les permite a las organizaciones un abastecimiento alineado con la demanda real del mercado, a partir de principios simples, pero poderosos).Así mismo, las soluciones de domicilios se han integrado exitosamente con plataformas como Domicilios.com, Uber Eats y Rappi. En la misma línea, aplicativos POS se han integrado con soluciones de fidelización de clientes como ‘LifeMiles’ y Puntos Colombia.“Por su parte, para empresas de ‘retail’ que necesitan análisis predictivos con base en herramientas de inteligencia artificial, hemos creado un ‘Joint Venture’ con la empresa colombiana Mutek. De otro lado, para empresas del sector de construcción e ingeniería nos hemos aliado con Edificar para la gestión de proyectos”, asevera Moreno.A la fecha, Siesa cuenta con más de 30 aliados que se han ido sumando a su ecosistema de aplicaciones.La línea de tiempo de la automatización¿Por qué automatizar? Aunque hoy, más que nunca, las organizaciones deben asumir los retos de una operación basada en la virtualidad y el teletrabajo, la automatización de procesos siempre ha impulsado la productividad empresarial.- Años 90Las soluciones ‘back office’, es decir, los ERP y herramientas de gestión financiera, comercial o manufactura, así como las soluciones ‘front office’ (o de gestión de punto de venta) han tenido una creciente demanda en Colombia desde la década de los 90.- El nuevo milenioA partir de 2010, se incrementó la demanda de soluciones de movilidad, CRM, automatización de fuerza de ventas y gestión de personal.- La nueva normalidadCon los cambios a los que se han enfrentado las compañías con la nueva normalidad (o la pospandemia), en estos últimos meses se ha incrementado la demanda de soluciones en la nube (SaaS o PaaS) y soluciones como e-Commerce, gestión de equipos de ventas de forma remota (Siesa eSales), domicilios (Siesa Delivery) y ‘software’ de gestión de recaudos (Siesa AGR).
