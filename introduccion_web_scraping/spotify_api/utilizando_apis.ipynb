# %% [markdown]
# # Utilizando APIS
#
# En este proyecto utilizaremos la API dew Spotify

# %% [markdown]
# ## Autenticación

# %% [markdown]
# [Guia de autenticación](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %% [markdown]
# ### Web API Reference
#
# [Link](https://developer.spotify.com/documentation/web-api/reference/)

# %%
import os
from IPython.display import JSON

# %%
client_id = os.getenv('SPOTIFY_CLIENT_ID')
client_secret = os.getenv('SPOTIFY_CLIENT_SECRET')

# %%
token_url = 'https://accounts.spotify.com/api/token'

# %%
import base64
import requests

def get_token(client_id, client_secret):
    client_str = '{client_id}:{client_secret}'.format(client_id=client_id, client_secret=client_secret)
    client_encode = base64.b64encode(client_str.encode("utf-8"))  # Codificado en Bytes
    client_encode = str(client_encode, "utf-8")  # Codificado en String
    params = {'grant_type': 'client_credentials'}
    header = {'Authorization' : f'Basic {client_encode}'}
    r = requests.post('https://accounts.spotify.com/api/token', headers=header, data=params)
    if r.status_code != 200:
        print('Error en el request.' , r.json())
        return None
    print(f'Token válido por {r.json()["expires_in"]}')
    return r.json()['access_token']

# %%
token = get_token(client_id, client_secret)
# Out:
# Token válido por 3600

# %% [markdown]
# ## Realizando la request a la API

# %%
artist_id = '74cb3MG0x0BOnYNW1uXYnM'

# %%
ep_artist = '/artists/{artist_id}'

# %%
url_base = 'https://api.spotify.com/v1'
url_completa = url_base+ep_artist.format(artist_id=artist_id)

# %%
header_get = {'Accept': 'application/json',
           'Content-Type' : 'application/json',
           'Authorization' : 'Bearer '+ token }
header_get
# Out:
# {'Accept': 'application/json',
#  'Content-Type': 'application/json',
#  'Authorization': 'Bearer BQCttTh1p5TP2zNVWrwItMqiGLKBQ3DXjK9OA3pj-5KB89zoWQfcA7z3aeP1IdAd2k3rwC6p48N4wf9Oot0'}

# %%
r = requests.get(url_completa, headers=header_get)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#  'followers': {'href': None, 'total': 2623073},
#  'genres': ['ccm',
#   'christian alternative rock',
#   'christian music',
#   'world worship',
#   'worship'],
#  'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#  'id': '74cb3MG0x0BOnYNW1uXYnM',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/99985d015601ee1d31630f19d5847f294cb784fa',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/5b6a5e16df100141e93bf8fb695042d375e96e77',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/94212e14a500ce6ad8f1f1a39e97680ad6d6bf17',
#    'width': 160}],
#  'name': 'Hillsong UNITED',
#  'popularity': 76,
#  'type': 'artist',
#  'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}

# %% [markdown]
# ## Realizando búsquedas en la API

# %%
url_busqueda = 'https://api.spotify.com/v1/search'

# %% [markdown]
# ### Buscando un artista

# %%
search_params = {'q':"Hillsong", 'type':'artist', 'market':'CO'}

# %%
busqueda = requests.get(url_busqueda, headers=header_get, params=search_params)

# %%
busqueda.status_code
# Out:
# 200

# %% [markdown]
# ### Resultados de la búsqueda de un artista

# %%
# busqueda.json()

# %%
import pandas as pd

# %%
df = pd.DataFrame(busqueda.json()['artists']['items'])
df.head()
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/3...
# 1  {'spotify': 'https://open.spotify.com/artist/7...
# 2  {'spotify': 'https://open.spotify.com/artist/3...
# 3  {'spotify': 'https://open.spotify.com/artist/7...
# 4  {'spotify': 'https://open.spotify.com/artist/4...
#
#                           followers  \
# 0   {'href': None, 'total': 380979}
# 1  {'href': None, 'total': 2623073}
# 2  {'href': None, 'total': 2419974}
# 3   {'href': None, 'total': 811525}
# 4     {'href': None, 'total': 6890}
#
#                                               genres  \
# 0                     [latin worship, world worship]
# 1  [ccm, christian alternative rock, christian mu...
# 2  [ccm, christian music, russian ccm, world wors...
# 3     [ccm, christian music, world worship, worship]
# 4                                    [world worship]
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/3phVKYqeq84...  3phVKYqeq84Ai91CHTQfNq
# 1  https://api.spotify.com/v1/artists/74cb3MG0x0B...  74cb3MG0x0BOnYNW1uXYnM
# 2  https://api.spotify.com/v1/artists/3SgHzT552wy...  3SgHzT552wy2W8pNLaLk24
# 3  https://api.spotify.com/v1/artists/7m4gF38CPAT...  7m4gF38CPATtHrk5HS42WZ
# 4  https://api.spotify.com/v1/artists/4d8bnn80rmL...  4d8bnn80rmLCwHU08DjGPS
#
#                                               images                    name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...     Hillsong en Español
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...         Hillsong UNITED
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...        Hillsong Worship
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...   Hillsong Young & Free
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Hillsong Instrumentals
#
#    popularity    type                                    uri
# 0          65  artist  spotify:artist:3phVKYqeq84Ai91CHTQfNq
# 1          76  artist  spotify:artist:74cb3MG0x0BOnYNW1uXYnM
# 2          77  artist  spotify:artist:3SgHzT552wy2W8pNLaLk24
# 3          71  artist  spotify:artist:7m4gF38CPATtHrk5HS42WZ
# 4          54  artist  spotify:artist:4d8bnn80rmLCwHU08DjGPS

# %%
df.sort_values(by='popularity', ascending=False).iloc[0]['id']
# Out:
# '3SgHzT552wy2W8pNLaLk24'

# %% [markdown]
# ### Buscando albums

# %%
ep_albums = f'/artists/{artist_id}/albums'
url_albums = url_base+ep_albums
url_albums
# Out:
# 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM/albums'

# %%
params = {'Country':'CO'}

# %%
albums_hu = requests.get(url_albums, headers=header_get, params=params)
albums_hu.status_code
# Out:
# 200

# %%
# albums_hu.json()

# %%
lista_albums = [(album['id'], album['name']) for album in albums_hu.json()['items']]
lista_albums
# Out:
# [('6Ek7aLgG88iYlJLKLvFdPT', 'People (Live)'),
#  ('3bMPLTN3fYcLAO2DJwPoBK', 'People (Live)'),
#  ('4l1CgmeovuVdf2iVmPxeV6', 'People (Live)'),
#  ('5tLfBSUv5KGNNOqbyKo1rD', 'People (Live)'),
#  ('2YRlXTl0heTfVc5oWmGLsg', 'People (Live)'),
#  ('5ZWmzqJe0RH6HdT4ntNaX2', 'Wonder'),
#  ('1jEMFRIpdPdNnIuKIBlf8O', 'Wonder'),
#  ('3UE6nEjBDG16jE3DvSyioz', 'Of Dirt And Grace (Live From The Land)'),
#  ('6GM646FRGtpTyYIYEAd3YZ', 'Of Dirt And Grace (Live From The Land)'),
#  ('4twr7zT1cX9NP5mk11FKDD', 'Empires'),
#  ('7wikPsBQQbAKQ0clBeJtKl', 'Empires'),
#  ('6Ug9xImpDW6SltESR789bp', 'Zion Acoustic Sessions (Live)'),
#  ('3mpGFlg6nbrJPMzwDWUFUU', 'The White Album [Remix Project]'),
#  ('2nKLgpaNIvgrmxT1GCLMb1', 'The White Album (Remix Project)'),
#  ('3A24aBx6jZCAgovIbZUubC', 'Zion (Deluxe Edition)'),
#  ('3HPeC2ejPE79o2y12dUzwh', 'Zion'),
#  ('7LHFVlsndw7HxDGJPWJS7S', 'Zion'),
#  ('7DVBC9uavDM2X6LGHSLjU3', 'Live In Miami'),
#  ('5lv8ALk4O8sxL8LXqsdtYo', 'Live In Miami'),
#  ('4Pzjki5DBNmEkceZAGUlqd', 'Aftermath')]

# %%
# Albums endpoint
album_id = lista_albums[-1][0]
print(album_id)
album_ep = f'/albums/{album_id}'
album_params = {'market':'CO'}
# Out:
# 4Pzjki5DBNmEkceZAGUlqd

# %%
# Album request
album_req = requests.get(url_base+album_ep+'/tracks', headers=header_get, params=album_params)
album_req.status_code
# Out:
# 200

# %%
album_req.json()
# Out:
# {'href': 'https://api.spotify.com/v1/albums/4Pzjki5DBNmEkceZAGUlqd/tracks?offset=0&limit=20&market=CO',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 457840,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4aWHuim48Pc3zMMPAIlgfC'},
#    'href': 'https://api.spotify.com/v1/tracks/4aWHuim48Pc3zMMPAIlgfC',
#    'id': '4aWHuim48Pc3zMMPAIlgfC',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/78YdgRljnYb2K9a38PQMAO'},
#     'href': 'https://api.spotify.com/v1/tracks/78YdgRljnYb2K9a38PQMAO',
#     'id': '78YdgRljnYb2K9a38PQMAO',
#     'type': 'track',
#     'uri': 'spotify:track:78YdgRljnYb2K9a38PQMAO'},
#    'name': 'Take Heart',
#    'preview_url': 'https://p.scdn.co/mp3-preview/8146a044c84a1d423554f702f06a1c83895ea415?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4aWHuim48Pc3zMMPAIlgfC'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 217066,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1sgrgtpvSk3hNtpX0MrJfq'},
#    'href': 'https://api.spotify.com/v1/tracks/1sgrgtpvSk3hNtpX0MrJfq',
#    'id': '1sgrgtpvSk3hNtpX0MrJfq',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/05mlGXaZieja1IT8LOK9FA'},
#     'href': 'https://api.spotify.com/v1/tracks/05mlGXaZieja1IT8LOK9FA',
#     'id': '05mlGXaZieja1IT8LOK9FA',
#     'type': 'track',
#     'uri': 'spotify:track:05mlGXaZieja1IT8LOK9FA'},
#    'name': 'Go',
#    'preview_url': 'https://p.scdn.co/mp3-preview/528442d1ba0663e8ce443c91558ac52a6a0ae429?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:1sgrgtpvSk3hNtpX0MrJfq'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 264013,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/736g0EO7Zx1D6G1LMvpgoI'},
#    'href': 'https://api.spotify.com/v1/tracks/736g0EO7Zx1D6G1LMvpgoI',
#    'id': '736g0EO7Zx1D6G1LMvpgoI',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6SdrlZFwXzbO51QtOldqy7'},
#     'href': 'https://api.spotify.com/v1/tracks/6SdrlZFwXzbO51QtOldqy7',
#     'id': '6SdrlZFwXzbO51QtOldqy7',
#     'type': 'track',
#     'uri': 'spotify:track:6SdrlZFwXzbO51QtOldqy7'},
#    'name': 'Like An Avalanche',
#    'preview_url': 'https://p.scdn.co/mp3-preview/b086abcc190bff655f1947305e36e8cfdb501f2c?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:736g0EO7Zx1D6G1LMvpgoI'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 343706,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/47wDxMd3a9bsATEa7yn86n'},
#    'href': 'https://api.spotify.com/v1/tracks/47wDxMd3a9bsATEa7yn86n',
#    'id': '47wDxMd3a9bsATEa7yn86n',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6vlUAv4VnfEwqT5qq3DL0R'},
#     'href': 'https://api.spotify.com/v1/tracks/6vlUAv4VnfEwqT5qq3DL0R',
#     'id': '6vlUAv4VnfEwqT5qq3DL0R',
#     'type': 'track',
#     'uri': 'spotify:track:6vlUAv4VnfEwqT5qq3DL0R'},
#    'name': 'Rhythms Of Grace',
#    'preview_url': 'https://p.scdn.co/mp3-preview/f4fa518df2597c841dfa6de707fbe28b6e661956?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:47wDxMd3a9bsATEa7yn86n'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 300533,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4xkreiCTlAC0lUwc8Mefvr'},
#    'href': 'https://api.spotify.com/v1/tracks/4xkreiCTlAC0lUwc8Mefvr',
#    'id': '4xkreiCTlAC0lUwc8Mefvr',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2gffdNFh2aPyfJgxPtZlUL'},
#     'href': 'https://api.spotify.com/v1/tracks/2gffdNFh2aPyfJgxPtZlUL',
#     'id': '2gffdNFh2aPyfJgxPtZlUL',
#     'type': 'track',
#     'uri': 'spotify:track:2gffdNFh2aPyfJgxPtZlUL'},
#    'name': 'Aftermath',
#    'preview_url': 'https://p.scdn.co/mp3-preview/a62fcf418510af6623fdd280793adbbf8b7ba72d?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4xkreiCTlAC0lUwc8Mefvr'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 174746,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2cLkswqWiwO5rAZRGKUOi3'},
#    'href': 'https://api.spotify.com/v1/tracks/2cLkswqWiwO5rAZRGKUOi3',
#    'id': '2cLkswqWiwO5rAZRGKUOi3',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2qlj8Ey0MnjIxDxmW8GiGe'},
#     'href': 'https://api.spotify.com/v1/tracks/2qlj8Ey0MnjIxDxmW8GiGe',
#     'id': '2qlj8Ey0MnjIxDxmW8GiGe',
#     'type': 'track',
#     'uri': 'spotify:track:2qlj8Ey0MnjIxDxmW8GiGe'},
#    'name': 'B.E.',
#    'preview_url': 'https://p.scdn.co/mp3-preview/d65af4143caf122869e0e8f54e807415da1fe1fb?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2cLkswqWiwO5rAZRGKUOi3'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 376746,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2NnDTgpGXcqDXmgsbE7COw'},
#    'href': 'https://api.spotify.com/v1/tracks/2NnDTgpGXcqDXmgsbE7COw',
#    'id': '2NnDTgpGXcqDXmgsbE7COw',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0IK6hlGAV7R8g6eOeDT06L'},
#     'href': 'https://api.spotify.com/v1/tracks/0IK6hlGAV7R8g6eOeDT06L',
#     'id': '0IK6hlGAV7R8g6eOeDT06L',
#     'type': 'track',
#     'uri': 'spotify:track:0IK6hlGAV7R8g6eOeDT06L'},
#    'name': 'Bones',
#    'preview_url': 'https://p.scdn.co/mp3-preview/906e2d1f7c67d6888e64402314546b530bd1523c?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:2NnDTgpGXcqDXmgsbE7COw'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 411346,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0nk5UBi7E5P4kOwcR9Qebn'},
#    'href': 'https://api.spotify.com/v1/tracks/0nk5UBi7E5P4kOwcR9Qebn',
#    'id': '0nk5UBi7E5P4kOwcR9Qebn',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3IgnwGUKsdHPkdXNlhfDqO'},
#     'href': 'https://api.spotify.com/v1/tracks/3IgnwGUKsdHPkdXNlhfDqO',
#     'id': '3IgnwGUKsdHPkdXNlhfDqO',
#     'type': 'track',
#     'uri': 'spotify:track:3IgnwGUKsdHPkdXNlhfDqO'},
#    'name': 'Father',
#    'preview_url': 'https://p.scdn.co/mp3-preview/15153ec0cd626f170a1fde7120e469e7c61088d7?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:0nk5UBi7E5P4kOwcR9Qebn'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 345986,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/61gJ3xei3CP5zbqphzxneF'},
#    'href': 'https://api.spotify.com/v1/tracks/61gJ3xei3CP5zbqphzxneF',
#    'id': '61gJ3xei3CP5zbqphzxneF',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/49yN3CUE4ITfKOaT4CSNBW'},
#     'href': 'https://api.spotify.com/v1/tracks/49yN3CUE4ITfKOaT4CSNBW',
#     'id': '49yN3CUE4ITfKOaT4CSNBW',
#     'type': 'track',
#     'uri': 'spotify:track:49yN3CUE4ITfKOaT4CSNBW'},
#    'name': 'Nova',
#    'preview_url': 'https://p.scdn.co/mp3-preview/52e0156ff2ab3e62bcb110d5270927f75160e6c6?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:61gJ3xei3CP5zbqphzxneF'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 216746,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2NkBWaTFR7ch1dazyKZZjG'},
#    'href': 'https://api.spotify.com/v1/tracks/2NkBWaTFR7ch1dazyKZZjG',
#    'id': '2NkBWaTFR7ch1dazyKZZjG',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4ggH0r1IdAyfjQqC0CHHse'},
#     'href': 'https://api.spotify.com/v1/tracks/4ggH0r1IdAyfjQqC0CHHse',
#     'id': '4ggH0r1IdAyfjQqC0CHHse',
#     'type': 'track',
#     'uri': 'spotify:track:4ggH0r1IdAyfjQqC0CHHse'},
#    'name': 'Light Will Shine',
#    'preview_url': 'https://p.scdn.co/mp3-preview/bb623301a39ac78475433277bfa12bd733366298?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2NkBWaTFR7ch1dazyKZZjG'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 365200,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/75AJg3qnPgeZr1Jw3orrzA'},
#    'href': 'https://api.spotify.com/v1/tracks/75AJg3qnPgeZr1Jw3orrzA',
#    'id': '75AJg3qnPgeZr1Jw3orrzA',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/45x7KgzwQkytwJCzkiboOT'},
#     'href': 'https://api.spotify.com/v1/tracks/45x7KgzwQkytwJCzkiboOT',
#     'id': '45x7KgzwQkytwJCzkiboOT',
#     'type': 'track',
#     'uri': 'spotify:track:45x7KgzwQkytwJCzkiboOT'},
#    'name': 'Search My Heart',
#    'preview_url': 'https://p.scdn.co/mp3-preview/2a0798c32225585520397555d44c1ca769bdc3df?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:75AJg3qnPgeZr1Jw3orrzA'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 433653,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0RFsNSQYTIS21OyLGfLy9C'},
#    'href': 'https://api.spotify.com/v1/tracks/0RFsNSQYTIS21OyLGfLy9C',
#    'id': '0RFsNSQYTIS21OyLGfLy9C',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6A0xmNbETs0w9TiIjgv48x'},
#     'href': 'https://api.spotify.com/v1/tracks/6A0xmNbETs0w9TiIjgv48x',
#     'id': '6A0xmNbETs0w9TiIjgv48x',
#     'type': 'track',
#     'uri': 'spotify:track:6A0xmNbETs0w9TiIjgv48x'},
#    'name': 'Awakening',
#    'preview_url': 'https://p.scdn.co/mp3-preview/861354657734ce871a58945f0f2e284eebcf13f9?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:0RFsNSQYTIS21OyLGfLy9C'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/74cb3MG0x0BOnYNW1uXYnM'},
#      'href': 'https://api.spotify.com/v1/artists/74cb3MG0x0BOnYNW1uXYnM',
#      'id': '74cb3MG0x0BOnYNW1uXYnM',
#      'name': 'Hillsong UNITED',
#      'type': 'artist',
#      'uri': 'spotify:artist:74cb3MG0x0BOnYNW1uXYnM'}],
#    'disc_number': 1,
#    'duration_ms': 235506,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0WsfqixIBT7GK5q0CXjeen'},
#    'href': 'https://api.spotify.com/v1/tracks/0WsfqixIBT7GK5q0CXjeen',
#    'id': '0WsfqixIBT7GK5q0CXjeen',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3gjSZTwWPcBMbZRqb8cR8w'},
#     'href': 'https://api.spotify.com/v1/tracks/3gjSZTwWPcBMbZRqb8cR8w',
#     'id': '3gjSZTwWPcBMbZRqb8cR8w',
#     'type': 'track',
#     'uri': 'spotify:track:3gjSZTwWPcBMbZRqb8cR8w'},
#    'name': 'Search My Heart (Radio Edit- Deluxe version)',
#    'preview_url': 'https://p.scdn.co/mp3-preview/6af6103abd7f1c9b6d67e7138fd3c1a80299eaaf?cid=cf30090c7b78406db5338bf76c496da7',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:0WsfqixIBT7GK5q0CXjeen'}],
#  'limit': 20,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 13}

# %%
album_req_items = album_req.json()['items']

# %%
[(track['id'], track['name']) for track in album_req_items]
# Out:
# [('4aWHuim48Pc3zMMPAIlgfC', 'Take Heart'),
#  ('1sgrgtpvSk3hNtpX0MrJfq', 'Go'),
#  ('736g0EO7Zx1D6G1LMvpgoI', 'Like An Avalanche'),
#  ('47wDxMd3a9bsATEa7yn86n', 'Rhythms Of Grace'),
#  ('4xkreiCTlAC0lUwc8Mefvr', 'Aftermath'),
#  ('2cLkswqWiwO5rAZRGKUOi3', 'B.E.'),
#  ('2NnDTgpGXcqDXmgsbE7COw', 'Bones'),
#  ('0nk5UBi7E5P4kOwcR9Qebn', 'Father'),
#  ('61gJ3xei3CP5zbqphzxneF', 'Nova'),
#  ('2NkBWaTFR7ch1dazyKZZjG', 'Light Will Shine'),
#  ('75AJg3qnPgeZr1Jw3orrzA', 'Search My Heart'),
#  ('0RFsNSQYTIS21OyLGfLy9C', 'Awakening'),
#  ('0WsfqixIBT7GK5q0CXjeen', 'Search My Heart (Radio Edit- Deluxe version)')]

# %%
def get_discography(artist_id, token, return_name=False, page_limit=50, country=None):
    ep_albums = f'/artists/{artist_id}/albums'
    url_albums = url_base+ep_albums
    req_header = {'Authorization' : 'Bearer '+ token}
    params = {'limit': page_limit,
              'offset': 0,
              'country': country}
    lista = []
    r = requests.get(url_albums, params=params,headers=req_header)
    
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
    
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=req_header)
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
def get_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    ep_tracks = f'/albums/{album_id}/tracks'
    url_tracks = url_base+ep_tracks
    req_header = {'Authorization' : 'Bearer '+ token}
    params = {'limit': page_limit,
              'offset': 0,
              'market': market}
    lista = []
    r = requests.get(url_tracks, params=params,headers=req_header)
    
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None
    
    if return_name:
        lista += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista += [item['id'] for item in r.json()['items']]
    
    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=req_header)
        if return_name:
            lista += [(item['id'], item['name']) for item in r.json()['items']]
        else:
            lista += [item['id'] for item in r.json()['items']]
    
    return lista

# %%
for album in get_discography(artist_id, token, return_name=True, country='CO'):
    print(album[1])
    for track in get_tracks(album[0], token, return_name=True, market='CO'):
        print('\t', track[1])

# %%
preview_url = 'https://p.scdn.co/mp3-preview/8146a044c84a1d423554f702f06a1c83895ea415?cid=cf30090c7b78406db5338bf76c496da7'
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
