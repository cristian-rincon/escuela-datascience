# %% [markdown]
# <a href="https://colab.research.google.com/github/cristian-rincon/escuela-datascience/blob/master/introduccion_web_scraping/project_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping página El Tiempo
#
# > eltiempo.com

# %%
import requests

# %%
url = 'https://eltiempo.com'

# %%
eltiempo = requests.get(url)

# %%
eltiempo.status_code
# Out:
# 200

# %%
# eltiempo.text

# %%
# eltiempo.content

# %%
eltiempo.headers
# Out:
# {'Server': 'nginx/1.10.2', 'Content-Type': 'text/html; charset=UTF-8', 'X-Server': 'etm25', 'x-url': '/', 'x-frame-options': 'sameorigin', 'X-Cacheable': 'YES', 'X-Varnish': '956069012 945230234', 'X-sc': 'x1', 'Content-Encoding': 'gzip', 'X-CDN': 'Incapsula', 'X-Iinfo': '4-52972822-52972836 SNNy RT(1593571650261 31309) q(0 0 0 0) r(0 0) U5', 'X-Akamai-Transformed': '9 - 0 pmb=mRUM,1', 'Cache-Control': 'private, max-age=120', 'Expires': 'Wed, 01 Jul 2020 02:53:01 GMT', 'Date': 'Wed, 01 Jul 2020 02:51:01 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive, Transfer-Encoding', 'Vary': 'Accept-Encoding', 'Server-Timing': 'cdn-cache; desc=HIT, edge; dur=1', 'version': 'desktop'}

# %%
eltiempo.request.headers
# Out:
# {'User-Agent': 'python-requests/2.23.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
eltiempo.request.method
# Out:
# 'GET'

# %%
eltiempo.request.url
# Out:
# 'https://www.eltiempo.com/'

# %% [markdown]
# ## Identificar la información de interés

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(eltiempo.text, 'lxml')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="text/javascript">
# ...

# %% [markdown]
# ### Menú principal

# %%
menu = soup.find('ul', attrs={'class':'default-menu'}).find_all('li')
menu
# Out:
# [<li class="opinion first" itemprop="name">
#  <a href="/opinion" itemprop="url">Opinión</a>
#  </li>, <li class="colombia" itemprop="name">
#  <a href="/colombia" itemprop="url">Colombia</a>
#  </li>, <li class="bogota" itemprop="name">
#  <a href="/bogota" itemprop="url">Bogotá</a>
#  </li>, <li class="mundo" itemprop="name">
#  <a href="/mundo" itemprop="url">Internacional</a>
#  </li>, <li class="politica" itemprop="name">
#  <a href="/politica" itemprop="url">Política</a>
#  </li>, <li class="justicia" itemprop="name">
#  <a href="/justicia" itemprop="url">Justicia</a>
#  </li>, <li class="economia" itemprop="name">
#  <a href="/economia" itemprop="url">Economía</a>
#  </li>, <li class="deportes" itemprop="name">
#  <a href="/deportes" itemprop="url">Deportes</a>
#  </li>, <li class="cultura" itemprop="name">
#  <a href="/cultura" itemprop="url">Cultura</a>
#  </li>, <li class="tecnosfera" itemprop="name">
#  <a href="/tecnosfera" itemprop="url">Tecnología</a>
# ...

# %%
item_menu = menu[0]
item_menu
# Out:
# <li class="opinion first" itemprop="name">
# <a href="/opinion" itemprop="url">Opinión</a>
# </li>

# %%
# item_menu.a
item_menu.a.get_text()
# Out:
# 'Opinión'

# %%
item_menu.a.get('href')
# Out:
# '/opinion'

# %%
links_menu = [item_menu.a.get('href') for item_menu in menu]
links_menu
# Out:
# ['/opinion',
#  '/colombia',
#  '/bogota',
#  '/mundo',
#  '/politica',
#  '/justicia',
#  '/economia',
#  '/deportes',
#  '/cultura',
#  '/tecnosfera',
#  '/vida',
#  '/salud',
#  '/unidad-investigativa',
#  'http://clasificados.eltiempo.com/']

# %%
section = requests.get( url + links_menu[0])
section
# Out:
# <Response [200]>

# %%
soup_section = BeautifulSoup(section.text, 'lxml')
soup_section.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <script type="text/javascript">\n   var _sf_startpt=(new Date()).getTime()\n  </script>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n  <script type="text/javascript">\n   window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,
# ...

# %%
feature_article = soup_section.find('div', attrs={'class':'container_col'})
feature_article
# Out:
# <div class="container_col">
# <article class="opinion-editorial-module " id="p68-m10204-10203-10205" itemscope="" itemtype="http://schema.org/NewsArticle"><h2 class="category-container">
# <a class="category page-link opinion opinion--editorial" href="/opinion/editorial" id="m10209-10208-10210">Editorial</a>
# </h2>
# <h3 class="title-container" itemprop="Headline">
# <a class="title page-link " href="/opinion/editorial/el-desempleo-no-cede-editorial-512892" id="m10215-1-10216">El desempleo no cede</a>
# </h3>
# <div class="epigraph-container">
# <a class="epigraph page-link " href="/opinion/editorial/el-desempleo-no-cede-editorial-512892" id="m10221-2-10222" style="width: auto;">La pérdida de más de 4,9 millones de puestos<br/>de trabajo en mayo ratifica que la reactivación económica debe incluir un plan para el empleo.</a>
# </div>
# <meta content="2020-06-30" itemprop="datePublished"/>
# <meta content="2020-06-30" itemprop="dateModified"/>
# ...

# %%
feature_article.a.get('href')
# Out:
# '/opinion/editorial'

# %%
article_list = soup_section.find('div', attrs={'class':'row-author-articles'})
article_list
# Out:
# <div class="row-author-articles row-columnistas1">
# <article class="opinion-author-module columnist-module " id="m5059-5058-5060" itemscope="" itemtype="http://schema.org/NewsArticle"><div class="recurso" itemtype="https://schema.org/NewsArticle">
# <figure class="author-image-container"><a class="image page-link " href="/opinion/columnistas/german-vargas-lleras/una-legislatura-atipica-columna-de-german-vargas-lleras-511972" id="m5064-5063-5065" itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject"><img alt="Germán Vargas Lleras" data-original="/files/image_80_80/uploads/2018/01/24/5a691b4a26233.jpeg" height="80px" src="..." style=" display: inline;" width="80px"/><meta content="80" itemprop="width"/>
# <meta content="80" itemprop="height"/>
# <meta content="https://www.eltiempo.com/files/image_80_80/uploads/2018/01/24/5a691b4a26233.jpeg" itemprop="url"/></a></figure>
# </div>
# <div class="content-container">
# <div class="author-container">
# ...

# %%
# TODO - Escribir el código para poder ingresar a otra sección de la página web
